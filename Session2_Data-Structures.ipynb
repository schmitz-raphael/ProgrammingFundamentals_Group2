# %% [markdown]
# # <p style="color:navy">Session 2. Data structures</p>
# ![data_strcutures.png](attachment:0c0cdf92-e047-4194-b1cf-9502cf566525.png)
# <div style="text-align: left">https://www.ibm.com/think/topics/data-structure</div>
#
#
# ```note
# A data structure is a way of formatting
# data so that it can be used by a computer
# program or other system in an efficient way.
# We structure data in different ways
# depending on what data we have,
# and what we want to do with it.
# ```
#
# Data structures combine **primitive data types** such as **numbers** (integers, decimal, complex), **characters**, **booleans**, etc. into a cohesive format. Alone, each of these primitive data types possesses only a single value. When they are combined in a data structure, they enable higher-level data operations such as **sorting**, **searching**, **insertion**, **deletion**, etc.

# %% [markdown]
# # Why are data structures important?
# Data structures make it easier for computers to **process large, complex sets of information**. By logically organizing data elements, data structures increase the efficiency of computer code.

# %% [markdown]
# # Data Types
# Data types are basic classifications. They are variables that are used throughout a program and can only exist with one classification. There are different classes of data type.

# %% [markdown]
# ## Primitive data types
# Primitive data types include **byte**, **short**, **int**, **long**, **float**, **double**, **Boolean**, **characters**, etc.:
# - **Boolean** values are data types that are either True or False (8 bits). So, a variable can be saved such that when its value is printed, the result will be saved as true or false.
# - **Character** is used to save a variable as a single character.
# - A **byte** can store numbers from -128 to 127. While these numbers can be stored as integers, or **int**, a **byte** uses less storage, so if we know the number is between those values, we can use a byte data type instead.
# - A **short** is a number between -32,768 and 32,767 (16 bits).
# - An **integer**, **int**, is used to store numbers between -2,147,483,648 and 2,147,483,647 ($2^{32}$).
# - **Long** is used to store numbers from -9,223,372,036,854,775,808 and 9,223,372,036,854,775,807 ($2^{64}$).
# - A **float** allows us to save a decimal number. Decimal numbers can also be saved as **double**, which has more precision than a **float**.
# - **Complex numbers**, representation of complex numbers
#
# | Size (bytes) | Size (bits) | Names | Signed range (two's complement representation) | Unsigned range |
# |:---:|:---:|:---|:---:|:---:|
# | 1 byte | 8 bits | Byte, octet | −128 to +127 | 0 to 255 |
# | 2 bytes | 16 bits | minimum size of `short` and `int` in C | −32,768 to +32,767 | 0 to 65,535 |
# | 4 bytes | 32 bits | minimum size of `long` in C | −2,147,483,648 to +2,147,483,647 | 0 to 4,294,967,295 |
# | 8 bytes | 64 bits | minimum size of `long` `long` in C, actual size of `long` for most modern C compilers | −9,223,372,036,854,775,808 to +9,223,372,036,854,775,807 | 0 to 18,446,744,073,709,551,615 |

# %% [markdown]
# <font color='red'>**/!\ Important** </font>
#
# Different languages may use different data types or similar types with different semantics. Examples:
# - Python programming language, `int` represents an arbitrary-precision integer which has the traditional numeric operations such as addition, subtraction, and multiplication.
# - Java programming language, the type `int` represents the set of 32-bit integers.
# - In Rust this 32-bit integer type is denoted `i32`

# %% [markdown]
# ![image.png](attachment:83f72d2d-18b1-48b8-8d31-c9af9c127f05.png)
# <div style="text-align: left">https://en.wikipedia.org/wiki/Data_type#/media/File:Python_3._The_standard_type_hierarchy-en.svg</div>

# %% [markdown]
# ## Composite types or non-primitive type
# ### Array (Data Type)
# Represents a collection of elements (values or variables), each selected by one or more indices (identifying keys) that can be computed at run time during program execution.
# Such a collection is usually called an array variable or array value. By analogy with the mathematical concepts **vector** and **matrix**, array types with one and two indices are often called vector type and matrix type, respectively. More generally, a multidimensional array type can be called a tensor type, by analogy with the mathematical concept, tensor.
# An element in row `i` and column `j` of an array `A` would be accessed by double indexing `A[i][j]`, in typical notation. In `C` and `C++` an element is called as `int A[1][2]`, in `Python` is simple `A[1][2]`
#
# ![image.png](attachment:35ba33a8-dc34-4d2f-9d10-10d69f68c8e5.png)
#
# Some programming languages support **array programming**, where operations and functions defined for certain data types are implicitly extended to arrays of elements of those types (e.g., `Matlab`, `Mathematica`, etc). But, these capabilities are also provided via standard extension libraries for other general purpose programming languages (such as the widely used `NumPy` library for `Python`).

# %% [markdown]
# You can use **nested lists** in `Python` to create matrices (i.e., two-dimensional lists). For example:

# %%
table = [[":(", ":)", ":(", ":)"],
         [":)", ":(", ":)", ":)"],
         [":(", ":)", ":)", ":("],
         [":)", ":)", ":)", ":("]]
 
print(table)
print(table[0][0])
print(table[2][3])
# Out:
# [[':(', ':)', ':(', ':)'], [':)', ':(', ':)', ':)'], [':(', ':)', ':)', ':('], [':)', ':)', ':)', ':(']]
# :(
# :(

# %% [markdown]
# ### String
# Computers store characters as numbers. Every character used by a computer corresponds to a unique number, and vice versa. This assignment must include more characters than you might expect. Many of them are invisible to humans, but essential to computers.
# Some of these characters are called printable, while others are named control characters, because their purpose is to control input/output devices.
# A sequence of characters representing text.
# People do not see this sign (or these signs), but are able to observe the effect of their application where the lines are broken.
#
# We can create virtually any number of character-number assignments, but life in a world in which every type of computer used a different character encoding would not be very convenient. This system has led to a need to introduce a universal and widely accepted standard implemented by (almost) all computers and operating systems all over the world.
#
# The one named ASCII (short for American Standard Code for Information Interchange) is the most widely used, and you can assume that nearly all modern devices (like computers, printers, mobile phones, tablets, etc.) use that code.
#
# ![image.png](attachment:350c7353-93e6-44e6-a128-5308da8c96d9.png)

# %% [markdown]
# #### Operations on Strings
# Strings can be concatenated (joined) and replicated.
# Python's strings are immutable sequences:
# - Strings doesn't allow you to use the `del` instruction to remove anything from a string.
# - Strings don't have the `append()` method – you cannot expand them in any way.
# - With the absence of the `append()` method, the `insert()` method is illegal, too.

# %%
alphabet = list("bcdefghijklmnopqrstuvwx")
# del alphabet[0]
# alphabet.append("A")
# alphabet.insert(0, "A")
alphabet.insert(0, "a")
alphabet.pop(10)
print(alphabet)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'l', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'v', 'w', 'x']

# %%
# There exists other methods to operate strings: 
alphabet = "a" + alphabet
alphabet = alphabet + "z"
print(alphabet)

# %% [markdown]
# - `ord()`: If you want to know a specific character's ASCII/UNICODE code point value, you can use a function named ord() (as in ordinal). The function needs a one-character string as its argument – breaching this requirement causes a TypeError exception, and returns a number representing the argument's code point.

# %%
print(ord("a"))# +1)

# %% [markdown]
# - `chr()`: if  you know the code point (number) and want to get the corresponding character, you can use a function named `chr()`. The function takes a code point and returns its character.

# %%
print(chr(97))
print(chr(945))

# %%
# Indexing
the_string = 'silly walks'

for indx in range(len(the_string)):
    print(the_string[indx], end=' ')
# Out:
# s i l l y   w a l k s

# %%
# Iterating
for character in the_string:
    print(character, end=' ')
# Out:
# s i l l y   w a l k s

# %%
# Slices
print(the_string[6:9])

# The in and not in operators
print("w" in the_string)
print("w" not in the_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Slices
# ----> 2 print(the_string[6:9])
#       3
#       4 # The in and not in operators
#       5 print("w" in the_string)
#
# NameError: name 'the_string' is not defined

# %% [markdown]
# - `min()` and `max()`

# %%
sentence = "Demonstrating min() and max()"
print('[' + min(sentence) + ']')
print('[' + max(sentence) + ']')
# Out:
# [ ]
# [x]

# %% [markdown]
# - The `index()` method searches the sequence from the beginning:
#     - its absence will cause a ValueError exception.
#     - index of the first occurrence of the argument

# %%
print("aAbByYzZaA".index("a"))
# Out:
# 0

# %% [markdown]
# - The `list()` function takes its argument (a string) and creates a new list containing all the string's characters, one per list element.

# %%
print(list("aAbByYzZaA"))
# Out:
# ['a', 'A', 'b', 'B', 'y', 'Y', 'z', 'Z', 'a', 'A']

# %% [markdown]
# - The `count()` method counts all occurrences of the element inside the sequence.

# %%
print("aAbBayYzZaA".count("Z"))
# Out:
# 1

# %% [markdown]
# #### String Methods
# - The `capitalize()` method
# - The `center()` method
# - The `endswith()` method
# - The `find()` method
# - The `isalnum()` method checks if the string contains only digits or alphabetical characters (letters), and returns True or False according to the result.
# - The `isalpha()` method is more specialized – it's interested in letters only.
# - The `isdigit()` method looks at digits only – anything else produces False as the result.
# - The `islower()` method s a fussy variant of isalpha() – it accepts lower-case letters only.
# - The `isspace()` method identifies whitespaces only – it disregards any other character (the result is False then).
# - The `isupper()` method is the upper-case version of islower() – it concentrates on upper-case letters only.
# - The `join()` method
# - The `lower()` method makes a copy of a source string, replaces all upper-case letters with their lower-case counterparts, and returns the string as the result.
# - The `lstrip()` method returns a newly created string formed from the original one by removing all leading whitespaces.
# - The `rstrip()` method do nearly the same as lstrips, but affect the opposite side of the string.
# - The `strip()` method combines the effects caused by rstrip() and lstrip() – it makes a new string lacking all the leading and trailing whitespaces.
# - The `replace()` method returns a copy of the original string in which all occurrences of the first argument have been replaced by the second argument.
# - The `split()` method does what it says – it splits the string and builds a list of all detected substrings.
# - The `startswith()` method is a mirror reflection of endswith() – it checks if a given string starts with the specified substring.
# - The `swapcase()` method makes a new string by swapping the cases of all letters within the source string: lower-case characters become upper-case, and vice versa.
# - The `title()` method performs a somewhat similar function – it changes every word's first letter to upper-case, turning all other ones to lower-case.
# - The `upper()` method makes a copy of the source string, replaces all lower-case letters with their upper-case counterparts, and returns the string as the result.

# %% [markdown]
# <font color='red'> **Reminder!** </font>
# Question about strings during the last session.
#
# - `reverse` method for `lists`
# - `reversed` method for `strings`

# %%
str_ = "palindrome"
reversed_str = str_[::-1]

# for char in reversed(str_):

[print(char) for char in reversed_str]
print("Reversed word:", reversed_str)
# Out:
# e
# m
# o
# r
# d
# n
# i
# l
# a
# p
# Reversed word: emordnilap

# %%
number_list = [1,2,3,4,5]
number_list.reverse()
print(number_list)
# Out:
# [5, 4, 3, 2, 1]

# %%
print(" ".join(["omicron", "pi", "rho"]))
print("[" + " tau ".lstrip() + "]")
print(".www.uni.lu.".strip("."))
print("This is it!".replace("is", "are"))
print("phi       chi\npsi".split())

# %% [markdown]
# ## Abstract data types (ADTs)
# ADTs include the information for the structure and design of data types.
# Abstract data structures include arrays and two-dimensional arrays, stacks, trees and binary trees, linked lists, queues, and more. Lists can contain multiple instances of the same data values. These lists are _countable_, so we can find how many elements are in the list, reorder them, remove items, add items, and so on. Lists are widely used as linked lists, arrays, or dynamic arrays:

# %% [markdown]
# ### List (abstract data type)
# A `list` is a sequential collection of elements that supports a set of operations without specifying the internal implementation. It provides an ordered way to store, access, and modify data.
# ![image.png](attachment:cc97af69-8430-4366-82d2-01ad24b46f7d.png)
# Lists are typically implemented either as linked lists (either singly or doubly linked) or as arrays, usually variable length or dynamic arrays.

# %% [markdown]
# ### Tuple
# - Ordered and unchangeable (immutable) collections of data.
# ```python
# my_tuple = (1, 2, True, "a string", (3, 4), [5, 6], None)
# ```
# - Commonly used for fixed collections, dictionary keys, function return values. Efficiency benefit when immutability is guaranteed.
# - The first and the clearest distinction between lists and tuples is the syntax used to create them - tuples prefer to use parenthesis, whereas lists like to see brackets, although it's also possible to create a tuple just from a set of values separated by commas.
# ```python
# tuple_1 = (1, 2, 4, 8)
# tuple_2 = 1., .5, .25, .125
# one_elem_tuple_2 = "one",
# ```
# - Do not try to modify a tuple's contents! Iti s not a list! We cannot use the `append()`, `del` methods. Instead:
#     - the `len()` function accepts tuples, and returns the number of elements contained inside;
#     - the `+` operator can join tuples together
#     - the `*` operator can multiply tuples, just like lists;
#     - the `in` and `not in` operators work in the same way as in lists.

# %%
my_tuple = (1, 10, 100)

t1 = my_tuple + (1000, 10000)
t2 = my_tuple * 3

print(len(t2))
print(t1)
print("t2", t2)
print(10 in my_tuple)
print(-10 not in my_tuple)

# %% [markdown]
# - You can access tuple elements by indexing them:

# %%
my_tuple = (1, 2.0, "string", [3, 4], (5, ), True)
print(my_tuple[3])

# %% [markdown]
# - Tuples are **immutable**, which means you cannot change their elements (you cannot append tuples, or modify, or remove tuple elements). The following snippet will cause an exception:

# %%
my_tuple[2] = "UNILU"

# %% [markdown]
# However, you can delete a tuple as a whole.
# ```python
# del my_tuple
# ```

# %% [markdown]
# ### Set
# Set items are **unordered**, **unchangeable**, and **do not allow duplicate** values.
# - Unordered means that the items in a set do not have a defined order.
# - Set items are unchangeable, meaning that we cannot change the items after the set has been created.
#
# Sets are suited for finding the **intersection/union** of two groups, such as finding those who live in a neighbourhood (set 1) and/or also own a car (set 2).
# Sets are written with curly brackets or by using the `set()` constructor.
# `{1, 1, 2, 3}`
# `set([1, 1, 2, 3])` will remove duplicates in the list to give a set.
#
# ```note
# The values True and 1 are considered the same value in sets, and are treated as duplicates. The same holds for False and 0.
# ```

# %%
thisset = {"apple", "banana", "cherry", 1, True, 1, 2, False, 0, False}
print(thisset)

# Add or Remove Elements in a Set
thisset.update(("cello", "violin"))
print(thisset)
thisset.remove(1)
print("remove", thisset)

# discard() removes an element from the set, but doesn't raise any error if does not exist
thisset.discard(5) 

# pop() removes and returns a random element from the set.
thisset.pop() 
print(thisset)

# clear() removes all elements from a set
thisset.clear()
print(thisset)

# %% [markdown]
# #### `set()` Operations
# - Set Union
# - Set Intersection
# - Set Difference
# - Set Symmetric Difference
#
# <font color='red'> **Homework:** </font>
# Difference between `set()` and `frozenset()`

# %% [markdown]
# ### Dictionary (`dict`)
# While the conceptual dictionary is an ADT, its underlying implementation can vary, commonly using data structures like hash tables for speed or binary search trees to maintain order, but can also be built using linked lists or sorted lists.
# To explain what the Python dictionary actually is, it is important to understand that it is literally a dictionary. The word you look for is named a `key`. The word you get from the dictionary is called a `value`.
#
# ```python
# my_dictionary = {
#     key1: value1,
#     key2: value2,
#     key3: value3,
# }
# ```

# %%
# How to build a dictionary?
dictionary = {
    "cat": "chat", 
    "dog": "chien", 
    "horse": "cheval"
}
phone_numbers = {
    'boss': 5551234567,
    'Suzy': 22657854310
}
empty_dictionary = {}
 
print(dictionary)
print(phone_numbers)
print(empty_dictionary)

# %% [markdown]
# This means that a dictionary is a set of key-value pairs:
# - each key must be **unique** − it's not possible to have more than one key of the same value;
# - a **key** may be any immutable type of object: it can be a number (integer or float), or even a string, but not a list;
# - the `len()` function works for dictionaries, too.
# - a dictionary is a **one-way tool**

# %% [markdown]
# #### Dictionary methods and functions
# - The `keys()` method

# %%
for key in dictionary.keys():
    print(key, "->", dictionary[key])

# %% [markdown]
# - `items()` returns tuples, where each tuple is a key-value pair.

# %%
for english, french in dictionary.items():
    print(english, "->", french)

# %% [markdown]
# - Modifying and adding values (`update()`)

# %%
dictionary['swan'] = 'cygne'
dictionary.update({"cat": "chat"})
del dictionary['dog']

# To remove the last item in a dictionary, you can use the popitem() method:
# dictionary.popitem() 
print(dictionary)

# %% [markdown]
# ### Summary and some properties of ADT
# |   Data Structure  |   Ordered  |   Mutable  |   Constructor  |   Example  |
# |:---:|:---:|:---:|:---:|:---:|
# |   List  |   Yes  |   Yes  |   `[ ]` or `list()`  |   `[5.7, 4, 'yes', 5.7]`  |
# |   Tuple  |   Yes  |   No  |   `()` or `tuple()`  |   `(5.7, 4, 'yes', 5.7)`  |
# |   Set  |   No  |   Yes  |   `{}`* or `set()`  |   `{5.7, 4, 'yes'}`  |
# |   Dictionary  |   No  |   No**  |   `{ }` or `dict()`  |   `{'Jun': 75, 'Jul': 89}`  |
#
# Data structures are concrete implementations of data types.
# How we add or remove elements from a collection, for example, is the data structure.

# %%
# Exercises

d1 = {'Adam Smith': 'A', 'Judy Paxton': 'B+'}
d2 = {'Mary Louis': 'A', 'Patrick White': 'C'}
d3 = {}
 
for item in (d1, d2):
    d3.update(item)
 
print(d3)

# %%
colors = (("green", "#008000"), ("blue", "#0000FF"))
colors_dictionary = dict(colors)
colors_dictionary_ = {}
for index in range(len(colors)):
    colors_dictionary_.update({colors[index][0]: colors[index][1]})

print(colors_dictionary)
print(colors_dictionary_)

# %%
# Another way of creating a dictionnary
dict([(1,2), (2,4), (3,9)])

# %% [markdown]
# ### Queue
# **Queue** ADT is a linear data structure that follows the First In, First Out (FIFO) principle.
# This means that the first data item to be added will be the first to be removed. Programmers often use this data structure to create priority queues, which are similar to waiting lists.
# However, in a queue ADT, the point of deletion and the point of insertion are done at two different ends.
#
# ![image.png](attachment:c8ee9b10-c8cc-422e-8636-b31fd689d8b9.png)
#
# #### Operations:
# - `enqueue()`: Insert an element at the end of the queue.
# - `dequeue()`: Remove and return the first element of the queue, if the queue is not empty.
# - `peek()`: Return the element of the queue without removing it, if the queue is not empty.
# - `size()`: Return the number of elements in the queue.
# - `isEmpty()`: Return true if the queue is empty; otherwise, return false.
#
#
# **Uses**: Queue data structures can be used to determine the next song in a playlist, the next user to have access to a shared printer or the next call to be answered in a call center.
#
# Example: Customers waiting to speak to a call center representative might be placed in a queue like this:
# ```python
# queue = [customer 1, customer 2, customer 3]
# queue = [customer 2, customer 3]
# ```

# %% [markdown]
# #### `collections.deque`
# It is also possible to use a list as a queue, where the first element added is the first element retrieved (“first-in, first-out”); however, lists are not efficient for this purpose. While `appends` and `pops` from the end of list are fast, doing `inserts` or `pops` from the beginning of a list is slow (because all of the other elements have to be shifted by one).
# Thus, to implement a queue, use `collections.deque` which was designed to have fast appends and pops from both ends.

# %%
from collections import deque
queue = deque(["Eric", "John", "Michael"])
print(queue, "\t\t\t <== Original queue")

queue.append("Terry")           # Terry arrives
queue.append("Graham")          # Graham arrives
print(queue, "\t <== After 2x append()") 

queue.popleft()                 # The first to arrive now leaves
queue.popleft()                 # The second to arrive now leaves
print(queue, "\t\t\t <== After 2x popleft()")

# %% [markdown]
# ### Stack
# Stack is a collection of elements and has two operations: `push` and `pop`. A `push` is used to add an element to the collection while a `pop` removes the most recent element.
# It follows the Last In, First Out (LIFO) principle.
# It allows elements to be added and removed only from one end, called the top of the stack.
#
# ![image.png](attachment:358f33fe-9eba-4ccd-b7a8-fafb21ec8d01.png)
#
# ![image.png](attachment:5461ac06-f202-4564-90d6-2ae7a56cca9e.png)
#
# #### Basic Operations
# - `push()`: Add an element to the top of a stack
# - `pop()`: Remove an element from the top of a stack
# - `peek()`: Get the value of the top element without removing it
# - `size()`: Return the number of elements in the stack.
# - `isEmpty()`: Check if the stack is empty
# - `isFull()`: Check if the stack is full
#
#
# **Uses**: Stacks can be used to help ensure the correct opening and closing of brackets or tags in computer codes, track recent browser history or undo recent operations in an application.
#
# Example: Many apps use stacks to keep track of user actions so they can easily be undone. For example, a text editor might keep a stack that looks like this:
#
# ```python
# recent_actions = [typing '.', space, typing 'T']
# ```
#
# When a user hits the “undo” button, the most recent action in the stack—"typing 'T'"—is undone. Now, the stack looks like this:
#
# ```python
# recent_actions = [typing '.', space]
# ```
#
# Python `list` used as a Stack.

# %% [markdown]
# #### Using list as stacks
# The `list` methods make it very easy to use a list as a stack, where the last element added is the first element retrieved (LIFO). To add an item to the top of the stack, use `append()`. To retrieve an item from the top of the stack, use `pop()` without an explicit index.

# %%
stack = [3, 4, 5]
stack.append(6)
stack.append(7)
print("After 2x append():\t", stack)

stack.pop()
print("After 1x pop():\t\t", stack)

stack.pop()
stack.pop()
print("After 2x pop():\t\t", stack)

# %%
class Stack:
    def __init__(self):
        self.stack = []
    
    def push(self, element):
        self.stack.append(element)
    
    def pop(self):
        if self.isEmpty():
            return "Stack is empty"
        return self.stack.pop()
    
    def peek(self):
        if self.isEmpty():
            return "Stack is empty"
        return self.stack[-1]
    
    def isEmpty(self):
        return len(self.stack) == 0
    
    def size(self):
        return len(self.stack)

# %%
# Create a stack
myStack = Stack()

myStack.push('A')
myStack.push('B')
myStack.push('C')
print("Stack:\t\t", myStack.stack)

print("Pop:\t\t", myStack.pop())

print("Peek:\t\t", myStack.peek())

print("isEmpty:\t", myStack.isEmpty())

print("Size:\t\t", myStack.size())

# %% [markdown]
# # Type of Data Structures
# # Linear Data Structures

# %% [markdown]
# ## Arrays
# They store data items of a similar type at adjacent memory locations. This structure enables items of the same type to be easily located and accessed.
#
# Uses: Common uses for arrays include sorting, storing, searching and accessing data. Arrays can also be used as a foundation for implementing other data structures, such as queues and stacks.
#
# **Example**: Algorithm: Find The Lowest Value in an Array.
#
# ```python
# my_array = [7, 12, 9, 4, 11]
# minVal = my_array[0]    # Step 1
#
# for i in my_array:      # Step 2
#     if i < minVal:      # Step 3
#         minVal = i
#
# print('Lowest value: ',minVal) # Step 4
# ```

# %% [markdown]
# ## Lists
# Each data element in the list is connected, or points, to the next one, regardless of where they are stored within the memory.
# **Key elements**:
# - Contiguous memory
# - Dynamic resizing
# - Costs:
#     - Access $O(1)$,
#     - Append $O(1)$,
#     - Insert/Delete at beginning/middle *O(N)* (requires shifting)
# <!-- - **Dynamic arrays** can be resized, which is important when choosing a data type. -->

# %% [markdown]
# ### Methods
# - `list.append(x)` adds a single element to the end of the list as a whole.
#
# ![image.png](attachment:77c34dbf-a747-4e5f-bb31-64458ad846d7.png)
# - `list.extend(iterable)` adds multiple elements from an iterable (such as a list, tuple, or set) to the list.
#
# ![image.png](attachment:7e3946bb-2f9a-4830-a81c-dcbdd51b58eb.png)
# - `list.insert(i, x)`
# - `list.remove(x)` removes the first item from the list whose value is equal to x. It raises a `ValueError` if there is no such item.
# - `list.pop([i])` removes the item at the given position in the list, and return it. If no index is specified, a.pop() removes and returns the last item in the list.
# - `list.clear()` removes all items from the list. Similar to `del a[:]`
# - `list.index(x[, start[, end]])`
# - `list.count(x)` returns the number of times `x` appears in the list.
# - `list.sort(*, key=None, reverse=False)`
# - `list.reverse()`
# - `list.copy()`

# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']
print(fruits.count('apple'))
print(fruits.count('tangerine'))

print(fruits.index('banana'))
print(fruits.index('banana', 4))  # Find next banana starting at position 4
print(fruits)

fruits.reverse()
print(fruits)

fruits.append('grape')
print(fruits)

fruits.sort()
print(fruits)

fruits.pop()
print(fruits)

# %% [markdown]
# <!-- ### Lists (Array-Based)
# - Stores elements in a contiguous block of memory.
# - Each element can be accessed directly using its index (constant time complexity, $O(1)$). -->

# %% [markdown]
# ### Linked Lists
# Consists of nodes, where each node contains the data and a reference (or link) to the next node in the sequence.
# Elements are not stored in contiguous memory locations, and accessing an element requires traversing the list from the head (linear time complexity, $O(n)$).
#
# Linked lists store data items in a linear order, with each item connected to the next item in the list. This structure makes it easy to insert new items or delete existing items without having to shift the entire collection of data.
#
# ![image.png](attachment:8221063e-0e05-4b4e-a4d4-ecce5d6b3b60.png)
#
# Uses: Linked lists are often used for frequent insertions and deletions in scenarios, such as web browser histories, media player playlists and undo or redo operations in applications.
#
# Example: A simplified version of a linked list of videos in a media player might look something like this:
# ```python
# Video 1 – Video 2 – Video 3
# ```
# ![image.png](attachment:image.png)
#
# Each object in the list points to the next, so when Video 1 is over, it will direct the media player to start Video 2.

# %% [markdown]
# <font color='red'> **What is the difference between list and linked list?** </font>
#
# | Feature | List (Array List) | Linked List |
# |-----------------------|---------------------------|------------------------------|
# | Memory Structure | Contiguous memory | Non-contiguous (nodes) |
# | Access Time | O(1) | O(n) |
# | Insertion/Deletion | O(n) | O(1) (if node reference is known) |
# | Memory Overhead | Lower (data only) | Higher (data + pointers) |
# | Use Cases | Fixed size, random access | Dynamic size, frequent changes|
# <!-- https://www.quora.com/What-is-the-difference-between-list-and-linkedlist -->

# %% [markdown]
# ![image.png](attachment:6130848e-d21e-4e38-a025-1f81dead5100.png)
# <div style="text-align: center"> https://devopedia.org/python-data-structures </div>

# %% [markdown]
# # Non-Linear Data Structures

# %% [markdown]
# # Trees
# A tree data structure, sometimes called a prefix tree, is useful for establishing hierarchical relationships among data elements. A single parent node sits on the top of the tree structure, with child subnodes branching out on subsequent levels beneath it.
# Different classes of trees, such as binary search trees, AVL trees and b-trees, have different properties and support different functions. For example, in a binary search tree, each node has at most 2 children. This structure helps support fast searches of data sets.
#
# ## Terminology
#            A (root)
#          /   |   \
#         B    C    D
#        / \        |
#       E   F       G
#
# - **Root**:
# The topmost node of the tree.
# Every tree has exactly one root.
# The root is `A`.
#
# - **Child**:
# A node directly connected below another node.
# Example: If `A` is connected to `B` and `C`, then `B` and `C` are children of `A`.
#
# - **Parent**:
# A node that has one or more children.
# Example: If `A` is above `B`, then `A` is the parent of `B`.
#
# - **Leaf (or External Node)**:
# A node with no children.
# Example: The last nodes at the bottom.
#
# - **Level of a Node**:
# The depth (distance) of a node from the root.
#     - Level 0 → A
#     - Level 1 → B, C, D
#     - Level 2 → E, F, G
#
# - **Height of a Node (`h`)**:
# The number of edges on the longest path from that node to a leaf.
# The height of a tree is the height of its root.
#     - 2 (longest path A → B → E or A → D → G)
#
# - **Degree of a Node**:
# The number of children a node has.
# Example: If a node has 3 children, its degree is 3.
# A leaf node has degree 0.
#     - A → 3 (B, C, D)
#     - B → 2 (E, F)
#     - C → 0 (leaf)
#     - D → 1 (G)
#     - E, F, G → 0 (leaf nodes)

# %% [markdown]
# ## Binary Trees
# A tree has no limitation on the number of children. A binary tree has a limitation as any node of the tree has at most two children: a left and a right child.
#
# ### Perfect binary tree
# A binary tree of height `h` having the maximum number of nodes is a perfect binary tree.
# For a given height `h`, the maximum number of nodes is $2^{h+1}-1$.
#
# ![image.png](attachment:c51172cb-2466-41bb-a934-93dcf8fbfdf3.png) \
# $n=2^{h+1}-1=7$.
#
# ### Complete binary tree
# It is a special type of binary tree where **all the levels of the tree are filled completely except the lowest level nodes** which are filled from as left as possible.
#
# ![image.png](attachment:66194b53-51f9-491e-9c93-bebc2ce3e29c.png) \
# $n=2^{h+1}-1=7$.
# But the number of nodes in the tree is 6. Hence it is not a perfect binary tree.
#
# ### Full binary tree
# Every node has either 2 children or 0 child.
#
# ![image.png](attachment:cd0b1dee-046e-4588-b9bc-73377b1c6891.png)

# %% [markdown]
# ## Heap Data Structure
# A Heap is a **complete binary tree** that stores data efficiently, allowing quick access to the maximum or minimum element, depending on the type of heap.
# ![image.png](attachment:9e86afaf-ad43-435c-a9e8-f4640872642c.png)
#
# It can either be a:
# - **Min Heap**: the key at the root must be the smallest among all the keys in the heap, and this property must hold true recursively for all nodes.
# - **Max Heap** follows the same principle, but with the largest key at the root.
#
# Heaps are usually used to implement priority queues, where the smallest (or largest) element is always at the root of the tree.
#
# ![image.png](attachment:f0f4ae9c-0360-4231-af98-a6afcffc80c1.png)
#
# ![image.png](attachment:1dd37946-1e76-414a-b3a9-5fe99d0b0aec.png)

# %% [markdown]
# <font color='red'> **Discussion** </font>
#
# ![image.png](attachment:9216c467-29f8-42b8-9406-9cdec907579f.png)
